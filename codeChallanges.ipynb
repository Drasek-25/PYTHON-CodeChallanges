# %% [markdown]
# ## Longest Common Prefix
# [Leetcode](https://leetcode.com/problems/longest-common-prefix/description/)
#
# Easy
#
# Write a function to find the longest common prefix string amongst an array of strings.
# If there is no common prefix, return an empty string "".
#
# **Example 1:**
#
# Input: strs = ["flower","flow","flight"]
# Output: "fl"
# Example 2:
#
# **Example 2:**
#
# Input: strs = ["dog","racecar","car"]
# Output: ""
# Explanation: There is no common prefix among the input strings.
#
# **Constraints:**
#
# 1 <= strs.length <= 200
# 0 <= strs[i].length <= 200
# strs[i] consists of only lowercase English letters.

# %%
def longest_common_prefix(strs):

    # Edge cases
    if len(strs) == 1: 
        return strs[0]
    if strs[0] == "": 
        return strs[0]

    #iterate indexes of first word.
    for i in range(0, len(strs[0])):
        # Set letter for comparrison from first word at eahc index
        letter = strs[0][i]
        
        # Iterates word in list after the first
        for j in range(1, len(strs)):
            # Catching words smaller than strs[0]
            if len(strs[j]) == i: 
                return strs[0][:i]
            # Catch when a non-match occurs and returning current position
            if letter != strs[j][i]:
                if i == 0: 
                    return ""
                else: 
                    return strs[0][:i]

    return strs[0][:i+1]    

example1 = ["flower","flow","flight"]
example2 = ["ab", "a"]
example3 = ["flower","flower","flower","flower"]

print(f"Answer : {longest_common_prefix(example1)}")
print(f"Answer : {longest_common_prefix(example2)}")
print(f"Answer : {longest_common_prefix(example3)}")
# Out:
# Answer : fl
# Answer : a
# Answer : flower

# %% [markdown]
# ---
# ## Length of Last Word
#
# [Leetcode](https://leetcode.com/problems/length-of-last-word/description/)
#
# Easy
#
# Given a string s consisting of words and spaces, return the length of the last word in the string.
#
# A word is a maximal substring consisting of non-space characters only.
#
# **Example 1:**
#
# Input: s = "Hello World"
# Output: 5
# Explanation: The last word is "World" with length 5.
#
# **Example 2:**
#
# Input: s = "   fly me   to   the moon  "
# Output: 4
# Explanation: The last word is "moon" with length 4.
#
# **Example 3:**
#
# Input: s = "luffy is still joyboy"
# Output: 6
# Explanation: The last word is "joyboy" with length 6.
#
# **Constraints:**
#
# 1 <= s.length <= 104
# s consists of only English letters and spaces ' '.
# There will be at least one word in s.

# %%
def lengthOfLastWord(s: str) -> int:  
    wordList = s.split()
    return len(wordList[-1])

example1 = "Hello World"
example2 = "   fly me   to   the moon  "
example3 = "luffy is still joyboy"

print(f"Answer : {lengthOfLastWord(example1)}")
print(f"Answer : {lengthOfLastWord(example2)}")
print(f"Answer : {lengthOfLastWord(example3)}")
# Out:
# Answer : 5
# Answer : 4
# Answer : 6

# %% [markdown]
# ---
# ## Add Two Numbers
#
# [Leetcode](https://leetcode.com/problems/add-two-numbers/description/)
#
# Medium
#
# You are given two non-empty linked lists representing two non-negative integers. The digits are stored in reverse order, and each of their nodes contains a single digit. Add the two numbers and return the sum as a linked list.
# You may assume the two numbers do not contain any leading zero, except the number 0 itself.
#
# **Example 1:**
#
# Input: l1 = [2,4,3], l2 = [5,6,4]
#
# Output: [7,0,8]
#
# Explanation: 342 + 465 = 807.
#
#
# **Example 2:**
#
# Input: l1 = [0], l2 = [0]
#
# Output: [0]
#
#
# **Example 3:**
#
# Input: l1 = [9,9,9,9,9,9,9], l2 = [9,9,9,9]
#
# Output: [8,9,9,9,0,0,0,1]
#
# **Constraints:**
#
# The number of nodes in each linked list is in the range [1, 100].
#
# 0 <= Node.val <= 9
#
# It is guaranteed that the list represents a number that does not have leading zeros.

# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

# Creating example linked lists
def createList(list):
    newLinkedList = ListNode(list[0])
    current = newLinkedList
    # Iterate through the stringed number adding the new numbers into the list for each index
    for num in list[1:]:
        current.next = ListNode(num)
        current = current.next

    return newLinkedList

def addTwoNumbers(l1, l2):
    #C reate strings to make the numbers out of linked list into a concatinated string
    totalNum1 = ""
    totalNum2 = ""

    # Specify head of first list, move through list concatinating string values of numbers in list
    current = l1
    while current is not None:
        totalNum1 += str(current.val)
        current = current.next

    #Do it again on second list
    current = l2
    while current is not None:
        totalNum2 += str(current.val)
        current = current.next

    # Take the both concatinated number strings, reverse both, convert to int, total them, 
    # convert to string to reverse the number, leave the number as a string to iterate over them
    totalNum3 = str(int(totalNum1[::-1]) + int(totalNum2[::-1]))[::-1]

    # Initialize a new linked list, then hold the current location on current
    # This is reduntant considering createList already exists, but I only have that function
    # so that this code works in both this notebook and Leetcode
    answer = ListNode(int(totalNum3[0]))
    current = answer
    #iterate through the stringed number adding the new numbers into the list for each index
    for num in totalNum3[1:]:
        current.next = ListNode(int(num))
        current = current.next

    #return answer as it is holding the head of the list, current is pointing at the last node
    return answer

# Since Leetcode needed a linkedlist as a return, we need a standalone function to make our answer readable here
def getAnswer(l3):
    answer = ""
    current = l3
    while current is not None:
        answer += str(current.val)
        current = current.next

    return answer

example_1A = createList([2,4,3])
example_1B = createList([5,6,4])

example_2A = createList([0])
example_2B = createList([0])

example_3A = createList([9,9,9,9,9,9,9])
example_3B = createList([9,9,9,9])

print(f"Answer: {getAnswer(addTwoNumbers(example_1A, example_1B))}")
print(f"Answer: {getAnswer(addTwoNumbers(example_2A, example_2B))}")
print(f"Answer: {getAnswer(addTwoNumbers(example_3A, example_3B))}")
# Out:
# Answer: 708
# Answer: 0
# Answer: 89990001

# %% [markdown]
# ---
# ## Who likes it?
#
# [Codewars](https://www.codewars.com/kata/5266876b8f4bf2da9b000362/train/python)
#
# You probably know the "like" system from Facebook and other pages. People can "like" blog posts, pictures or other items. We want to create the text that should be displayed next to such an item.
#
# Implement the function which takes an array containing the names of people that like an item. It must return the display text as shown in the examples:
#
#
# []                                -->  "no one likes this"
#
# ["Peter"]                         -->  "Peter likes this"
#
# ["Jacob", "Alex"]                 -->  "Jacob and Alex like this"
#
# ["Max", "John", "Mark"]           -->  "Max, John and Mark like this"
#
# ["Alex", "Jacob", "Mark", "Max"]  -->  "Alex, Jacob and 2 others like this"
#
#
# Note: For 4 or more names, the number in "and 2 others" simply increases.

# %%
def likes(names):
    # There might be a way to write this with less code, but it would reduce
    # readability, and honestly what would be the point? the syntax is so specific.
    if len(names) == 0:
        return "no one likes this"
    elif len(names) == 1:
        return f"{names[0]} likes this"
    elif len(names) == 2:
        return f"{names[0]} and {names[1]} like this"
    elif len(names) == 3:
        # Willing to buy Oxford comma!
        return f"{names[0]}, {names[1]} and {names[2]} like this"
    else:
        return f"{names[0]}, {names[1]} and {len(names)-2} others like this"
    
example1 = []
example2 = ["Peter"] 
example3 = ["Jacob", "Alex"]  
example4 = ["Max", "John", "Mark"]   
example5 = ["Alex", "Jacob", "Mark", "Max"]

print(f"Answer: {likes(example1)}")
print(f"Answer: {likes(example2)}")
print(f"Answer: {likes(example3)}")
print(f"Answer: {likes(example4)}")
print(f"Answer: {likes(example5)}")
# Out:
# Answer: no one likes this
# Answer: Peter likes this
# Answer: Jacob and Alex like this
# Answer: Max, John and Mark like this
# Answer: Alex, Jacob and 2 others like this
